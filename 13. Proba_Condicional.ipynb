# %% [markdown]
# ---
#
# <p align="center">
#   <img src="https://raw.githubusercontent.com/lacamposm/Diplomado_Metodos_UCentral/main/data/images/imagen_ucentral.jpg" alt="logo_Ucentral" width="400px" height="300px">
# </p>

# %% [markdown]
# # ___Diplomado: Métodos Estadísticos para el Análisis de Datos___
#
# ## ___Docente: Luis Andres Campos Maldonado.___
#
# ### ___Estadística descriptiva bivariada.___
#
#
# ***Probabilidad Condicional.***
#
# Para la introducción a esta sección veamos el siguiente vídeo.
#
# https://www.youtube.com/watch?v=D7KKlC0LOyw
#
#
# ---

# %% [markdown]
# ##Funciones de probabilidades

# %% [markdown]
# ###Probabilidad Condicional

# %%
def prob_conditional(a_inter_b, p_b):
    p_ab = a_inter_b/p_b
    return round(p_ab, 3)

def prob_conditional_ac(p_ab):
    p_acb = 1-p_ab
    return round(p_acb, 3)

# %%
import numpy as np
import pandas as pd
from scipy.special import factorial, perm, comb
#herramientas para conteo

# %% [markdown]
# ###Probabilidad

# %% [markdown]
# Consideremos la siguiente situación: Tenemos una urna que contiene 10 bolas rojas y 15 bolas blancas. De las 10 bolas rojas , 4 tienen un huequito y 6 no tienen huequito. De las 15 blancas, 9 tienen un huequito y 6 no tienen huequito. El experimento será: extraer una bola de la urna
#
# a. ¿Cuál es la probabilidad que la bola tenga un huequito?
#
# b. Si sabemos de antemano que la bola seleccionada es roja. ¿Cuál es la probabilidad que la bola tenga un huequito?
#
# **Solución:** En este caso, consideremos los siguientes eventos
#
# - A : La bola extraída tiene huequito
#
# - B : La bola extraída es roja
#
# Supongamos que no tenemos ninguna información previa. Por lo tanto:
#
# - $P(A)=\dfrac{13}{25}$, adicionalmente
#
# - $P(B)=\dfrac{10}{25}=\dfrac{2}{5}$
#
# Ahora, para responder b) supongamos que sabemos de antemano que la bola es roja. En este caso, el espacio muestral se reduce y por lo tanto.
#
# - $P(A)=\dfrac{4}{10}=\dfrac{2}{5}=0.4$

# %%
#a) La bola extraída tiene huequito
p_a = 13/25
print(f"Probabilidad de que la bola extraída tiene huequito {round(p_a, 3)*100}")

#b) La bola extraída es roja
p_b = 10/25
print(f"Probabilidad de que la bola extraída sea roja {round(p_b, 3)*100}%")

#b.1) bola roja con huequito
p_b1 = 4/10
print(f"Probabilidad de que la bola extraída sea roja con huequitos {round(p_b1, 3)*100}%")
# Out:
# Probabilidad de que la bola extraída tiene huequito 52.0
# Probabilidad de que la bola extraída sea roja 40.0%
# Probabilidad de que la bola extraída sea roja con huequitos 40.0%

# %% [markdown]
# ###Ejemplo anterior (Probabilidad Condicional: Bola Roja)
#
#
# Consideremos la siguiente situación: Tenemos una urna que contiene 10 bolas rojas y 15 bolas blancas. De las 10 bolas rojas , 4 tienen un huequito y 6 no tienen huequito. De las 15 blancas, 9 tienen un huequito y 6 no tienen huequito.
#
# Si sabemos de antemano que la bola seleccionada es roja. ¿Cuál es la probabilidad que la bola tenga un huequito?
#
# $$P(A \, | \, B)= \dfrac{P(A \cap B)}{P(B)}$$

# %%
##Númerador: probabilidad de que sea una bola con huequito de las rojas
a_huequito = 4
omega = 25
p_a_intersectado_b = a_huequito/omega
print(f"probabilidad de que la bola sea roja y con huequito es de {round(p_a_intersectado_b, 3)*100}%")

##Denominador: probabilidad de que sea una bola roja
b_roja = 10
omega = 25
p_b = b_roja/omega

p_ab = p_a_intersectado_b/p_b
print(f"la probabilidad buscada es de {round(p_ab, 3)*100}")
# Out:
# probabilidad de que la bola sea roja y con huequito es de 16.0%
# la probabilidad buscada es de 40.0

# %% [markdown]
# ### ***Definición [La probabilidad condicional]***
#
#  Sean $A$ y $B$ dos eventos tales que $P(B)>0$, la probabilidad del evento $A$ dado $B$ o condicionado a la ocurrencia del evento $B$ es
#
# $$P(A \, | \, B)= \dfrac{P(A \cap B)}{P(B)}$$
# Veamos como aplica el ejemplo anterior
#
# $P(A \, | \, B)= \dfrac{P(A \cap B)}{P(B)}=\dfrac{\dfrac{4}{25}}{\dfrac{10}{25}}=\dfrac{4}{10}=\dfrac{2}{5}=0.4$
#
#
# ### ***Ejemplo***
#
# Un  taller  sabe  que  por  término  medio  acuden  por  la  mañana  tres  automóviles con problemas eléctricos, ocho con problemas mecánicos y tres con problemas de cerradura, y  por  la  tarde  dos  con  problemas  eléctricos,  tres  con  problemas  mecánicos  y  uno  con problemas de cerradura.
#
#    + Representar la información en una tabla
#
#    + ¿Cuál es el porcentaje que acuden por la tarde?
#
#    + ¿Cuál es la probabilidad de que un automóvil con problemas eléctricos acuda por la mañana?
#
# Veamos la solución

# %%
import pandas as pd

data = {"electricos":[3,2], "mecanicos":[8,3], "cerradura":[3,1]}
df = pd.DataFrame(data, index= ["mañana","tarde"])
df["total_jornada"] = df.sum(axis = 1) ## Total por filas.
df.loc["total_servicios"]= df.sum(axis = 0) ## Total por columnas.
df["total_porcion"] = df["total_jornada"]/df.loc["total_servicios","total_jornada"]
tmp = (df.loc["total_servicios"]/df.loc["total_servicios","total_jornada"])*100
df.loc["total_servicios_%"] = tmp
df = round(df,2)
df.loc["total_servicios_%","total_porcion"] = "TOTALES"
###
def style_color(v, props=''):
    return props if type(v) == str  else None
s2 = df.style.applymap(style_color, props='color:red;'); s2
# Out:
# <style type="text/css">
# #T_0a749_row3_col4 {
#   color: red;
# }
# </style>
# <table id="T_0a749" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a749_level0_col0" class="col_heading level0 col0" >electricos</th>
#       <th id="T_0a749_level0_col1" class="col_heading level0 col1" >mecanicos</th>
#       <th id="T_0a749_level0_col2" class="col_heading level0 col2" >cerradura</th>
#       <th id="T_0a749_level0_col3" class="col_heading level0 col3" >total_jornada</th>
#       <th id="T_0a749_level0_col4" class="col_heading level0 col4" >total_porcion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a749_level0_row0" class="row_heading level0 row0" >mañana</th>
#       <td id="T_0a749_row0_col0" class="data row0 col0" >3.000000</td>
#       <td id="T_0a749_row0_col1" class="data row0 col1" >8.000000</td>
#       <td id="T_0a749_row0_col2" class="data row0 col2" >3.000000</td>
#       <td id="T_0a749_row0_col3" class="data row0 col3" >14.000000</td>
#       <td id="T_0a749_row0_col4" class="data row0 col4" >0.700000</td>
#     </tr>
#     <tr>
#       <th id="T_0a749_level0_row1" class="row_heading level0 row1" >tarde</th>
#       <td id="T_0a749_row1_col0" class="data row1 col0" >2.000000</td>
#       <td id="T_0a749_row1_col1" class="data row1 col1" >3.000000</td>
#       <td id="T_0a749_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_0a749_row1_col3" class="data row1 col3" >6.000000</td>
#       <td id="T_0a749_row1_col4" class="data row1 col4" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_0a749_level0_row2" class="row_heading level0 row2" >total_servicios</th>
#       <td id="T_0a749_row2_col0" class="data row2 col0" >5.000000</td>
#       <td id="T_0a749_row2_col1" class="data row2 col1" >11.000000</td>
#       <td id="T_0a749_row2_col2" class="data row2 col2" >4.000000</td>
#       <td id="T_0a749_row2_col3" class="data row2 col3" >20.000000</td>
#       <td id="T_0a749_row2_col4" class="data row2 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a749_level0_row3" class="row_heading level0 row3" >total_servicios_%</th>
#       <td id="T_0a749_row3_col0" class="data row3 col0" >25.000000</td>
#       <td id="T_0a749_row3_col1" class="data row3 col1" >55.000000</td>
#       <td id="T_0a749_row3_col2" class="data row3 col2" >20.000000</td>
#       <td id="T_0a749_row3_col3" class="data row3 col3" >100.000000</td>
#       <td id="T_0a749_row3_col4" class="data row3 col4" >TOTALES</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# $A$ = "El automovil tiene que daño va en la mañana"
#
# $B$ = "El automovil tiene daño electrico"

# %%
print("*"*80)
print(f"La probabilidad del evento A, es decir, que el daño sea la mañana es: {round(14/20,3)*100}%")
print(f"La probabilidad del evento B, es decir, que el daño sea eléctrico es: {round(5/20,3)*100}%")
print("*"*80)
# Out:
# ********************************************************************************
# La probabilidad del evento A, es decir, que el daño sea la mañana es: 70.0%
# La probabilidad del evento B, es decir, que el daño sea eléctrico es: 25.0%
# ********************************************************************************

# %% [markdown]
# La probabilidad requerida es:
#
# $P(A|B)=\frac{P(A\cap B)}{P(B)}$

# %%
##Evento a (tiene que daño... va en la mañana)
a_mañana = 14      ###va en la mañana
omega = 20
p_a = a_mañana/omega
print(f"La probabilidad de que el automovil vaya en la mañana y tenga un daño electrico es de {round(p_a, 3)*100}%")

##Evento b (daño electrico)
b_electrico = 5   ###"daño electrico"
p_b = b_electrico/omega
print(f"la probablidad de que el automovil sea electrico es de {round(p_b, 3)*100}%")

## la probabilidad de que sea un auto electrico y vaya en la mañana por daño
p_a_intersectado_b = 3/omega
p_ab = p_a_intersectado_b/p_b
print(f"La probabilidad de que sea un auto electrico y vaya en la mañana por daño {round(p_ab, 3)*100}%")
# Out:
# La probabilidad de que el automovil vaya en la mañana y tenga un daño electrico es de 70.0%
# la probablidad de que el automovil sea electrico es de 25.0%
# La probabilidad de que sea un auto electrico y vaya en la mañana por daño 60.0%

# %%
print("La probabilidad de A intersectado con B, es, que el daño sea elétrico y en la mañana es:", round(3/20,3))
print("La probabilidad buscada es:", round((3/20)/(5/20),3) )
# Out:
# La probabilidad de A intersectado con B, es, que el daño sea elétrico y en la mañana es: 0.15
# La probabilidad buscada es: 0.6

# %% [markdown]
# ## ***Algunas propiedades de la probabilidad condicional***
#
#
# Sea $E$ un evento fijo del espacio muestral $\Omega$, es decir, $E \subseteq \Omega$, podemos definir la siguiente función:
#
# $$P(\star \,  \mid \, E) \, : \, \mathscr{P}(\Omega)  \longrightarrow [0,1]$$
#
# que toma un evento del conjunto $\mathscr{P}(\Omega)$ y le asigna un elemento en el conjunto $[0,1]$
#
#
#
# #### ***Ejercicio para casa # 1:***
#
# Verificar que $P(A^c \mid B) = 1 - P(A \mid B)$
#
#
# ## ***Regla del producto:***
#
#  Si tenemos dos eventos $A$ y $B$, con $P(B)>0$ entonces
#
# $$P(A \cap B) = P( A \, \mid \, B)  P(B)= P( B \, \mid \, A)  P(A)$$
#
# ### ***Propiedad:***
#
# Si $A_{1},A_{2}, \dots, A_{n}$ son eventos con $P(A_{1}\cap A_{2}\dots\cap A_{n-1})>0$ entonces:
#
# $$P(A_{1}\cap A_{2}\dots\cap A_{n}) = P(A_{1})P(A_{2}|A_{1})P(A_{3}|A_{1}\cap A_{2})\dots P(A_{n}|A_{1}\cap A_{2}\cap \dots\cap A_{n-1})$$

# %% [markdown]
# ##Ejercicio No. 1

# %% [markdown]
# Para verificar la **relación entre la probabilidad condicional de un evento complementario y la probabilidad condicional del evento original**, podemos usar la definición de probabilidad condicional:
#
# $$P(A|B) = \frac{P(A \cap B)}{P(B)}$$
#
# Donde:
# - $P(A|B)$ es la probabilidad condicional de A dado B.
# - $P(A \cap B)$ es la probabilidad de que ocurran ambos eventos A y B.
# - $P(B)$ es la probabilidad de que ocurra el evento B.
#
# Ahora, examinemos la probabilidad condicional de $A^c$ dado B:
#
# $$P(A^c|B) = \frac{P(A^c \cap B)}{P(B)}$$
#
# Dado que $A$ y $A^c$ son eventos complementarios, $A$ y $A^c$ son mutuamente excluyentes, lo que significa que no pueden ocurrir al mismo tiempo. Esto implica que $A \cap B$ y $A^c \cap B$ son también mutuamente excluyentes. Por lo tanto, podemos escribir:
#
# $$P(A^c \cap B) = P(B) - P(A \cap B)$$
#
# Sustituyendo esto en la ecuación de $P(A^c|B)$, obtenemos:
#
# $$P(A^c|B) = \frac{P(B) - P(A \cap B)}{P(B)}$$
#
# Ahora, simplifiquemos la expresión:
#
# $$P(A^c|B) = \frac{P(B)}{P(B)} - \frac{P(A \cap B)}{P(B)}$$
#
# $$P(A^c|B) = 1 - \frac{P(A \cap B)}{P(B)}$$
#
# Finalmente, llegamos a la relación que queremos verificar:
#
# $$P(A^c|B) = 1 - P(A|B)$$
#
# Entonces, la relación $P(A^c|B) = 1 - P(A|B)$ es válida.

# %% [markdown]
# #### ***Ejemplo.***
#
# Consideremos la situación: Tenemos una urna que contiene 10 bolas rojas y 15 bolas blancas. De las 10 bolas rojas , 4 tienen un huequito y 6 no tienen huequito. De las 15 blancas, 9 tienen un huequito y 6 no tienen huequito. Se extraen dos bolas sin reposición ¿Cuál es la probabilidad de extraer una bola roja y luego una blanca?
#
# *Solución* Definimos los eventos
#
# - A: La primera bola es roja
#
# - B: La segunda bola es blanca
#
# El ejercicio nos pide la probabilidad de $A \cap B$. Usando **la regla del producto** tenemos
#
# $$P(A \cap B) = P( B \, \mid \, A)  P(A) = \dfrac{15}{24} *\dfrac{10}{25}=\dfrac{1}{4}$$

# %%
##bolas blancas
a= 15
##bolas rojas
b = 10
##intersectacion
omega = a+b

#Regla del producto
p_a = a/(omega-1)
p_b = b/omega
p_ba= p_a*p_b
print(f"la probabilidad buscada es de {round(p_ba, 3)*100}%")
# Out:
# la probabilidad buscada es de 25.0%

# %% [markdown]
# ### ***Definición:***
#  Una colección de eventos $A_1, A_2, A_3 , \dots, A_k$ se dice una *partición* del espacio muestral $\Omega$ si
#
# - $A_{i} \cap A_{j} = \phi$ para todo $i \neq j$.
#
# - $\bigcup \limits_{i=1}^{k} A_i =\Omega$
#
# ### ***Teorema de Probabilidad Total:***
#  Sea $A_1, A_2, A_3 , \dots, A_k$ una partición del espacio muestral $\Omega$ y $B$ un evento o suceso cualquiera, entonces
#
# $$P(B)= \sum \limits_{i=1}^{k} P(B \, \mid \, A_{i}) P(A_{i})$$
#
# #### ***Comentario***
#
# $$B=B \cup \Omega = B \cap \bigcup \limits_{i=1}^k A_i = \bigcup \limits_{i=1}^{k} (A_i \cap B)$$
#
# Si $A_i \cap A_j = \phi$ entonces $(A_i \cap B) \cap (A_j \cap B) = \phi$
#
# Por lo tanto,
#
# $$P(B)= P \left (\bigcup \limits_{i=1}^{k} (A_i \cap B) \right)= \sum \limits_{i=1}^k P(B  \cap A_i) = \sum \limits_{i=1}^k P(B \, \mid A_i) P(A_i)$$
#
# **Regla del producto**: $$\sum \limits_{i=1}^k P(B \, \mid A_i) P(A_i)$$

# %% [markdown]
# ### ***Ejemplos de aplicación de teorema de probabilidad total.***
#
#
# #### ***Ejemplo 1.***
#
# Supongamos que tenemos tres cajas con bombillas. La primera contiene 10 bombillas, de las cuales hay cuatro fundidas; en la segunda hay seis bombillas, estando una de ellas fundida, y la tercera caja hay tres bombillas fundidas de un total de ocho. ¿Cuál es la probabilidad de que al tomar una bombilla al azar de una cualquiera de las cajas, esté fundida?

# %% [markdown]
# ***Sol:***
#
# Sea $B$ el evento: $\text{La bombilla está fundida}$.
#
# Sean $A_{i}=\text{La bombilla es de la caja $i$}$, con $i=1,2,3$. --> espacio muestral
#
# Del T. de la probabildad total, se sigue que:
#
# $P(B) = P(B|A_{1})P(A_{1}) + P(B|A_{2})P(A_{2})+P(B|A_{3})P(A_{3})$
#
# Como:
#
# - $P(B|A_{1})$ = $\frac{4}{10}$
# - $P(B|A_{2})$ = $\frac{1}{6}$
# - $P(B|A_{3})$ = $\frac{3}{8}$
# - $P(A_{1})$ = $\frac{10}{24}$
# - $P(A_{2})$ = $\frac{6}{24}$
# - $P(A_{3})$ = $\frac{8}{24}$

# %%
p = (4/10)*(10/24) + (1/6)*(6/24) + (3/8)*(8/24)
print("La probabilidad del evento B es:", round(p,3))
# Out:
# La probabilidad del evento B es: 0.333

# %% [markdown]
# #### ***Ejemplo 2.***
#
# En un acuario se tienen solo 2 especies de peces, el 40% son de la especie azul y el 60% son de la especie roja. De la especie azul, el 30% son machos; mientras que, de la especie roja, el 40% son hembras. ¿Cuál es la probabilidad de que un pez elegido aleatoriamente en el acuario sea macho?

# %% [markdown]
# ***Solución:***
#
# Sean $M:$ el pez es macho y $R:$ el pez es rojo.--->$P(M)$ ???
#
# Luego:
#
# $P(M) = P(M|R)P(R)+P(M|R^{c})P(R^{c})$

# %%
p = 0.6*0.6 + 0.3*0.4
print(f"La probabilidad de que el pez sea macho es: {round(p, 3)*100}%")
# Out:
# La probabilidad de que el pez sea macho es: 48.0%

# %% [markdown]
# #### ***Ejercicio para la casa # 2:***
#
# El $42\%$ de la población activa de cierto país está formada por mujeres. Se sabe que un $24\%$ de las mujeres y un $16\%$ de los hombres están en un paro. ¿Cuál es la probabilidad de que una persona elegida al azar de la población activa en este país esté en el paro?

# %% [markdown]
# ***Solución:***
#
# Sean **P**: Paro,  **H**: Hombre, **M**: Mujer
#
# $P(PARO) = P(P|H)P(H) + P(P|M)P(M)$

# %%
p1 = 16 #P(P|H)
p2 = 58 #P(H)
p3 = 24 #P(P|M)
p4 = 42 #P(M)

p = (p1*p2) + (p3*p4)
print(f"la probabilidad buscada es de {round(p/100, 3)}%")
# Out:
# la probabilidad buscada es de 19.36%

# %% [markdown]
# ### ***Teorema de Bayes.***
#
#
# El Teorema de Bayes es una proposición enunciada por Thomas Bayes en el siglos XVIII, pero se conoció hasta después de su muerte por Richard Price y es una teorema basado en las probabilidades condicionales.
#
# Recordemos que en general $P(A \mid B)$ no coincide con $P(B \mid A)$
# La regla de Bayes o también denominada *regla inversa*, establece una relación entre estas dos probabilidades:
#
# Esto representa la probabilidad de que ocurra el evento A dado que ya sabemos que el evento B ha ocurrido. En otras palabras, estamos calculando la probabilidad de A bajo la condición de que sabemos que B es cierto.
#
# $$P(A|B) = \frac{P(B|A)P(A)}{P(B)}$$
#
#
# - $P(B)$ es conocida como la probabilidad a **priori**
#
# - $P(B \mid A)$ es la probabilidad a posteriori.
#
# Si lo vemos como una relación causa-efecto, la idea es determinar la probabilidad de la causa, cuando se ha inducido un determinado efecto.

# %% [markdown]
# La razón principal por la que $P(A \mid B)$ no coincide con $P(B \mid A)$
# se debe a la forma en que se definen estas probabilidades condicionales y a las diferentes relaciones que pueden existir entre los eventos A y B. Aquí hay una breve explicación:
#
# **Probabilidad Condicional** $P(A \mid B)$: Esto representa la probabilidad de que ocurra el evento A dado que ya sabemos que el evento B ha ocurrido. En otras palabras, estamos calculando la probabilidad de A bajo la condición de que sabemos que B es cierto.
#
# $$P(A|B) = \frac{P(A \cap B)}{P(B)}$$
#
# **Probablidad Condicional** $P(B \mid A)$: Esto representa la probabilidad de que ocurra el evento B dado que ya sabemos que el evento A ha ocurrido. En este caso, estamos calculando la probabilidad de B bajo la condición de que sabemos que A es cierto.
# En resumen, $P(A \mid B)$  y  $P(B \mid A)$ son probabilidades condicionales que se calculan bajo diferentes condiciones. A menos que los eventos A y B estén relacionados de una manera específica, no hay razón para que estas dos probabilidades sean iguales.
#
# $$P(A|B) = \frac{P(B|A)P(A)}{P(B)}$$

# %% [markdown]
# #### ***Ejemplo.***
#
# En un salón de clase, la probabilidad de que a un estudiante seleccionado al azar le guste el helado es del $60 \%$, mientras que la probabilidad de que a un estudiante le guste la torta es del $36 \%$. Además, se sabe que la probabilidad de que a un alumno le guste la torta dado que le gusta el helado es del $40\%$. Calcular la probabilidad de que a un estudiante le guste el helado, dado que le gusta la torta.
#
# **Solución:** $66,67 \%$

# %% [markdown]
# Sean $A:$ Le gusta el helado, $B:$ Le gusta la torta ----> $P(A|B)$ ???
#
# Tenemos: $P(B|A) = 0.4$, $P(A)=0.6$ y $P(B)=0.36$, asi:
#
# $P(A|B) = \frac{P(B|A)P(A)}{P(B)}= \frac{0.4*0.6}{0.36}=0.667$

# %%
p = 0.4*0.6/0.36
string = """La probabilidad de a un estudiante le guste el helado dado que le gusta la
torta es:"""
print(string, round(p,3))
# Out:
# La probabilidad de a un estudiante le guste el helado dado que le gusta la
# torta es: 0.667

# %% [markdown]
# ## ***Teorema de Bayes (forma extendida):***
#  Sea $A_1, A_2, A_3 , \dots, A_k$ una partición del espacio muestral $\Omega$ y $B$ un evento o suceso cualquiera tal que $P(B)>0$, entonces
#
# $$P(A_j \mid B) = \dfrac{P(A_j)P(B \mid A_j)}{P(B)}=\dfrac{P(A_j)P(B \mid A_j)}{\sum \limits_{i=1}^{k} P(B \mid A_i)P(A_i)}$$
# *Demostración:* Aplicamos la definición de la probabilidad condicional y luego usamos el teorema de probabilidad total.
#
# $$P(A_j \mid B) = \dfrac{P(A_j \cap B)}{P(B)}=\dfrac{P(B \mid A_j)P(A_j)}{\sum \limits_{i=1}^{k} P(B \mid A_i)P(A_i)}$$
# Este Teorema describe cómo es posible "revisar" la probabilidad inicial de un evento o probabilidad a priori para reflejar la información adicional que provee la ocurrencia de un evento relacionado.

# %% [markdown]
# #### ***Ejemplo.***
#
# probabilidad total:
# Una empresa que fabrica zapatos posee tres máquinas $M_1$ , $M_2$ y $M_3$, las cuales producen el $45\%$ , $30\%$ y $25\%$ respectivamente, del total de zapatos producidos en la fábrica. Los porcentajes de producción defectuosa en estas máquinas son del $3\%$, $4\%$ y $5\%$ respectivamente. Calcular las siguientes probabilidades
#
#   + Se selecciona un par de zapatos al azar. ¿Cuál es la probabilidad de que salga defectuoso? (Teorema de la probaiblidad total)
#
#   $$P(B) = P(B|A_{1})P(A_{1}) + P(B|A_{2})P(A_{2})+P(B|A_{3})P(A_{3})$$
#
#   + Se selecciona un par de zapatos al azar y resulta ser defectuoso. ¿Cuál es la probabilidad de que se haya producido por la máquina $M_2$? (Teorema de bayes)
#
# $$P(A|B) = \frac{P(B|A)P(A)}{P(B)}$$

# %% [markdown]
# ***Solución:***
#
# Sean $M_{i}:$ El par de zapatos proviene de la maquina $i$, con $i=1,2,3$ y $D:$ El par de zapatos es defectuoso.

# %%
## Probabilidad p de ser defectuso.
p = 0.45*0.03 + 0.30*0.04 + 0.25*0.05
print("La probabilidad de ser defectuso es:", round(p,4))
# Out:
# La probabilidad de ser defectuso es: 0.038

# %%
# Probabilidad de que provenga de la maquina 2, dado que es defectuoso.
p1 = (0.04*0.30)/p
print("La probabilidad de que provenga de la maquina 2, dado que es defectuoso es:", round(p1,4))
# Out:
# La probabilidad de que provenga de la maquina 2, dado que es defectuoso es: 0.3158

# %% [markdown]
# #### ***Ejercicio para casa:***
#
# El $60\%$ de los tornillos producidos por una fábrica proceden de la máquina A y el $40\%$  de  la máquina  B.  La  proporción  de  defectuosos  en  A  es  $0.1$  y  en B  es  $0.5$.  ¿Cuál  es  la probabilidad de que un tornillo de dicha fábrica sea defectuoso? ¿Cuáles la probabilidad de que, sabiendo que un tornillo es defectuoso, proceda de la máquina A?
#
# #### ***Ejercicio para casa:***
#
# Use el Teorema de Bayes para resolver el ejercicio del vídeo visto en la clase anterior.

# %%
a1 = 0.6
a2 = 0.4
ba1 = 0.1
ba2 = 0.5

pb = a1*ba1 + a2*ba2
print(f"la probabilidad de que un tornillo salga defectuoso es de: {round(pb, 3)*100}%")
# Out:
# la probabilidad de que un tornillo salga defectuoso es de: 26.0%

# %%
p2 = ba1*a1/pb
print(f"la probabilidad de que venga de la maquina A y sea defectuoso es de {round(p2, 3)*100}%")
# Out:
# la probabilidad de que venga de la maquina A y sea defectuoso es de 23.1%

# %% [markdown]
# ## ***Definición[Independencia de eventos]***
#
# Dos eventos o sucesos se dicen *independientes* si la ocurrencia de uno de ellos no modifica la probabilidad del otro. Es decir, $P(A \mid B) = P(A)$ y $P(B \mid A) =P(B)$. En otras palabras son eventos son independientes si
#
# $$P(A \cap B)=P(A)P(B)$$
#
# #### ***Ejemplo.***
#
# De una urna que contiene 4 bolas negras y 6 blancas se extraen dos bolas sin reposición , ¿cuál es la probabilidad de que la segunda bola sea blanca, sabiendo
# que la primera es negra? ¿Los eventos descritos son independientes? Realice el mismo ejercicio con reposición.

# %% [markdown]
# ***Solución:***
#
# $A: \text{Segunda bola es blanca}$
#
# $B: \text{La primera bola es negra}$
#
# 1. Con reposición:
#
# $P(A|B)=\frac{6}{10}$
#
# $P(A)=\frac{6}{10}$
#
# ***INDEPENDIENTES***
#
# 2. Sin reposición:
# $P(A|B)=\frac{6}{9}$
#
# Depende de lo se obtuvo en la primera elección.
#
# ***NO INDEPENDIENTES.***

# %%
omega = 10
bola_blanca = 6/omega
print(f"la probabilidad de que la segunda sea blanca con reposición es de {bola_blanca}")
# Out:
# la probabilidad de que la segunda sea blanca con reposición es de 0.6

# %%
bola_blanca1 = 6/(omega-1)
print(f"la probabilidad de que la segunda bola sea blanca sin reposición {round(bola_blanca1, 3)}")
# Out:
# la probabilidad de que la segunda bola sea blanca sin reposición 0.667

# %% [markdown]
# ### ***Propiedades de la independencia de eventos***
#
#
# - Dados dos eventos $A$ y $B$ mutuamente excluyentes, es decir, $A \cap B= \phi$ y si $P(A)>0$ y $P(B)>0$, entonces $A$ y $B$ no son independientes.
#
# - Si $P(B)=0$, entonces $B$ es independiente de cualquier evento $A$ talque $P(A)>0$.
#
# - Si $A \subseteq B$ y $P(A)>0$ y $P(B)<1$, entonces $A$ y $B$ no son independientes.
#
# - Si $A$ y $B$ son sucesos independientes, $A$ y $B^c$ también son independientes.
#
# - Si $A$ y $B$ son sucesos independientes, $A^c$ y $B^c$ también son independientes.
#
# Podemos generalizar la independencia a más eventos: Los eventos $A_1, A_2, A_3 , \dots, A_k$ son independientes si
#
# $$P(A_{i_1} \cap A_{i_2} \cap \dots \cap A_{i_k})=P(A_{i_1})P(A_{i_2}). \dots P(A_{i_k})$$
# Para cualquier conjunto de índices $\{i_k\}$ en $\{1,2,3 \dots , n\}$

# %% [markdown]
# ## ***Ejemplo adicional en clase.***
#
# #### ***Ejemplo 1:***
#
#
# Tres amigos desean comprar licor en una tienda de cadena, todos son menores de edad. El cajero desea verificar la edad, les pide su documento de identidad. Luego de revisar y negarles la venta, se los devuelve al azar. La probabilidad de que ninguno de los amigos reciba su propio documento es...

# %% [markdown]
# ***Solución:***
#
# Sean $A$ el evento que ningún joven recibe su documento.
#
# Sean $B_{i}$ el $i$-esimo joven recibe su documento, con $i=1,2,3$.
#
# Nos preguntan por ---> $P(B_{1}^{c}\cap B_{2}^{c}\cap B_{3}^{c})$
# ver ley de morgan
#
#
#  **Ley de Morgan $$(A \cap B)^c = A^c \cup B^c$$**
#
#  **Ley de Morgan $$(A \cup B)^c = A^c \cap B^c$$**

# %% [markdown]
# $P(B_{1}^{c}\cap B_{2}^{c}\cap B_{3}^{c})$ = $P((B_{1}\cup B_{2}\cup B_{3})^{c})$ = $1-P(B_{1}\cup B_{2}\cup B_{3})$

# %% [markdown]
# Tenemos esto:
#
# $P(B_{1}\cup B_{2}\cup B_{3}) = P(B_{1})+P(B_{2})+P(B_{3})-P(B_{1}\cap B_{2})-P(B_{1}\cap B_{3})-P(B_{2}\cap B_{3})+P(B_{1}\cap B_{2}\cap B_{3})$

# %% [markdown]
# Como: (ver probabilidad condicional)
#
# $P(B_{1}\cap B_{2})=P(B_{2}|B_{1})P(B_{1})=\frac{1}{2}*\frac{1}{3}=\frac{1}{6}$, igual para las demás intersecciones dobles.
#
# **Probabilidad Condicional: $$P(A|B) = \frac{P(A \cap B)}{P(B)}$$**

# %% [markdown]
# Como:
#
# $P(B_{1}\cap B_{2}\cap B_{3})=P(B_{1})*P(B_{2}|B_{1})*P(B_{3}|B_{1}\cap B_{2})
# =\frac{1}{3}*\frac{1}{2}*1=\frac{1}{6}$.

# %%
p_union = 1/3+1/3+1/3-1/6-1/6-1/6+1/6
print("La probabilidad de que ningún joven reciba su documento es:", round(1-p_union,4))
# Out:
# La probabilidad de que ningún joven reciba su documento es: 0.3333

# %% [markdown]
# #### ***Ejercicio para la casa:***
#
# En una urna hay 20 bolas: 4 azules, 3 rojas, 7 blancas y 6 verdes. Se extraen 2 bolas (sin sustitución). Responder:
#
# 1. ¿Cuál es la probabilidad de que la primera sea azul y la segunda roja?
# 2. ¿cuál es la probabilidad de que ambas sean del mismo color?
# 3. ¿Cuál es la probabilidad de que la segunda sea azul o roja?
# 4. ¿Cuál es la probabilidad de que la primera no sea blanca y la segunda sea verde?
# 5. ¿Cuál es la probabilidad de que la segunda sea verde dado que la primera no era blanca?

# %% [markdown]
# ---
#
# > <font color="Magenta" FONT SIZE=6> Para entregar.</font>
#
# ---
#
#
# > <font color="Magenta" FONT SIZE=4>**Ejercicio 1:**</font>
#
# Un estudio realizado en personas de una región determinada mostró que $20\%$ de ellas eran fumadoras. La probabilidad de muerte debida a cáncer pulmonar, dado que una persona fumaba, era alrededor de $10$ veces la probabilidad de muerte debida a cáncer pulmonar de una persona que no fumaba. Si la Probabilidad de muerte debida a cáncer pulmonar en la región es $0.006$, ¿cuál es la probabilidad de
# muerte debida a cáncer pulmonar dado que una persona es fumadora?
#
# > <font color="Magenta" FONT SIZE=4>**Ejercicio 2:**</font>
#
# Una urna contiene 3 bolas rojas y 7 negras. Los jugadores $A$ y $B$ extraen consecutivamente una bola de la urna, hasta que una bola roja es seleccionada. ¿A qué es igual la probabilidad de que el jugador $A$ extraiga la bola roja? Suponga que la extracción se hace sin sustitución y que el jugador $A$ inicia el juego.
#
# > <font color="Magenta" FONT SIZE=4>**Ejercicio 3:**</font>
#
# En una urna hay 3 bolas rojas y 3 bolas negras. Se extraen 3 bolas de la urna simultaneamente. Si se extraen solamente bolas negras o solo rojas entonces se lanza un dado corriente una vez, en caso contario se lanzan 2 dados corrientes.
#
# 1. Calcular la probabilidad que el número total obtenido, en el o los lanzamientos, sea mayor o igual a 4.
# 2. Clacular la probabibilidad condicional de que solo se hayan extraído bolas negras o bolas rojas dado que el número total obtenido es 4.
